# %%
#!pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Obtaining dependency information for langchain_groq from https://files.pythonhosted.org/packages/bb/e7/aec777a50942059be78b0677135f866a2ead2447e308e3f075f5ff9a93a6/langchain_groq-0.2.4-py3-none-any.whl.metadata
#   Downloading langchain_groq-0.2.4-py3-none-any.whl.metadata (3.0 kB)
# Collecting groq<1,>=0.4.1 (from langchain_groq)
#   Obtaining dependency information for groq<1,>=0.4.1 from https://files.pythonhosted.org/packages/61/2a/a96b0a1bba13474364fdabdc086da2866324bebfa4a4e51bcf8318831d3b/groq-0.16.0-py3-none-any.whl.metadata
#   Downloading groq-0.16.0-py3-none-any.whl.metadata (14 kB)
# Collecting langchain-core<0.4.0,>=0.3.33 (from langchain_groq)
#   Obtaining dependency information for langchain-core<0.4.0,>=0.3.33 from https://files.pythonhosted.org/packages/98/78/463bc92174555cc04b3e234faa169bb8b58f36fff77892d7b8ae2b4f58e4/langchain_core-0.3.33-py3-none-any.whl.metadata
#   Downloading langchain_core-0.3.33-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\shrip\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (3.5.0)
# Collecting distro<2,>=1.7.0 (from groq<1,>=0.4.1->langchain_groq)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from groq<1,>=0.4.1->langchain_groq)
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\shrip\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.10.8)
# Requirement already satisfied: sniffio in c:\users\shrip\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.2.0)
# Collecting typing-extensions<5,>=4.10 (from groq<1,>=0.4.1->langchain_groq)
#   Obtaining dependency information for typing-extensions<5,>=4.10 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\shrip\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain_groq) (6.0)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.33->langchain_groq)
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<0.4,>=0.1.125 (from langchain-core<0.4.0,>=0.3.33->langchain_groq)
#   Obtaining dependency information for langsmith<0.4,>=0.1.125 from https://files.pythonhosted.org/packages/47/3b/02313e378f6328ada43ee43ecc81a398b4f68e207c94770d1ed6aac6cca2/langsmith-0.3.4-py3-none-any.whl.metadata
#   Downloading langsmith-0.3.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\shrip\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain_groq) (24.2)
# Collecting pydantic<3,>=1.9.0 (from groq<1,>=0.4.1->langchain_groq)
#   Obtaining dependency information for pydantic<3,>=1.9.0 from https://files.pythonhosted.org/packages/f4/3c/8cc1cc84deffa6e25d2d0c688ebb80635dfdbf1dbea3e30c541c8cf4d860/pydantic-2.10.6-py3-none-any.whl.metadata
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\shrip\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain_groq) (8.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\shrip\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (3.4)
# Requirement already satisfied: certifi in c:\users\shrip\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (2023.7.22)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/87/f5/72347bc88306acb359581ac4d52f23c0ef445b57157adedb9aee0cd689d2/httpcore-1.0.7-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq)
#   Obtaining dependency information for h11<0.15,>=0.13 from https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl.metadata
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shrip\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain_groq) (2.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq)
#   Obtaining dependency information for orjson<4.0.0,>=3.9.14 from https://files.pythonhosted.org/packages/00/f8/bb60a4644287a544ec81df1699d5b965776bc9848d9029d9f9b3402ac8bb/orjson-3.10.15-cp311-cp311-win_amd64.whl.metadata
#   Downloading orjson-3.10.15-cp311-cp311-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB ? eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in c:\users\shrip\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (2.31.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\shrip\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (1.0.0)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq)
#   Obtaining dependency information for zstandard<0.24.0,>=0.23.0 from https://files.pythonhosted.org/packages/be/a2/4272175d47c623ff78196f3c10e9dc7045c1b9caf3735bf041e65271eca4/zstandard-0.23.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq)
#   Obtaining dependency information for pydantic-core==2.27.2 from https://files.pythonhosted.org/packages/e8/ef/013f07248041b74abd48a385e2110aa3a9bbfef0fbd97d4e6d07d2f5b89a/pydantic_core-2.27.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrip\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shrip\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (1.26.16)
# Downloading langchain_groq-0.2.4-py3-none-any.whl (14 kB)
# Downloading groq-0.16.0-py3-none-any.whl (109 kB)
#    ---------------------------------------- 0.0/109.7 kB ? eta -:--:--
#    ---------------------------------------- 109.7/109.7 kB 3.2 MB/s eta 0:00:00
# Downloading langchain_core-0.3.33-py3-none-any.whl (412 kB)
#    ---------------------------------------- 0.0/412.7 kB ? eta -:--:--
#    ----------------- ---------------------- 184.3/412.7 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 412.7/412.7 kB 5.2 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 4.0 MB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB ? eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.3.4-py3-none-any.whl (333 kB)
#    ---------------------------------------- 0.0/333.3 kB ? eta -:--:--
#    --------------------------------------- 333.3/333.3 kB 21.5 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ---------------------------------------- 0.0/431.7 kB ? eta -:--:--
#    ---------------------------------------- 431.7/431.7 kB ? eta 0:00:00
# Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 33.4 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 31.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 21.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading orjson-3.10.15-cp311-cp311-win_amd64.whl (133 kB)
#    ---------------------------------------- 0.0/133.6 kB ? eta -:--:--
#    ---------------------------------------- 133.6/133.6 kB ? eta 0:00:00
# Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl (495 kB)
#    ---------------------------------------- 0.0/495.4 kB ? eta -:--:--
#    --------------------------------------- 495.4/495.4 kB 32.3 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Installing collected packages: zstandard, typing-extensions, orjson, jsonpatch, h11, distro, annotated-types, pydantic-core, httpcore, pydantic, httpx, langsmith, groq, langchain-core, langchain_groq
#   Attempting uninstall: zstandard
#     Found existing installation: zstandard 0.19.0
#     Uninstalling zstandard-0.19.0:
#       Successfully uninstalled zstandard-0.19.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.8
#     Uninstalling pydantic-1.10.8:
#       Successfully uninstalled pydantic-1.10.8
# Successfully installed annotated-types-0.7.0 distro-1.9.0 groq-0.16.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 jsonpatch-1.33 langchain-core-0.3.33 langchain_groq-0.2.4 langsmith-0.3.4 orjson-3.10.15 pydantic-2.10.6 pydantic-core-2.27.2 typing-extensions-4.12.2 zstandard-0.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.3 requires pydantic<2.0, but you have pydantic 2.10.6 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.

# %%
from langchain_groq import ChatGroq

# %%
chat = ChatGroq(temperature=0, groq_api_key="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", model_name="llama-3.3-70b-versatile")
response=chat.invoke('What is groq')
print(response.content)
# Out:
# Groq is a technology company that specializes in developing artificial intelligence (AI) and machine learning (ML) hardware and software solutions. The company was founded in 2016 by Jonathan Ross and a team of experienced engineers and researchers from Google, Facebook, and other top tech companies.
#
# Groq's primary focus is on creating high-performance, low-power AI computing platforms that can be used for a wide range of applications, including natural language processing, computer vision, and autonomous vehicles. The company's products are designed to accelerate AI workloads, reducing the time and energy required to train and deploy AI models.
#
# Some of the key features of Groq's technology include:
#
# 1. **Tensor Streaming Processor (TSP)**: Groq's TSP is a custom-designed processor that is optimized for AI workloads. It uses a unique architecture that allows for high-bandwidth, low-latency data transfer and processing.
# 2. **Software-defined architecture**: Groq's platform is designed to be highly flexible and programmable, allowing developers to customize the architecture to suit their specific needs.
# 3. **Low power consumption**: Groq's technology is designed to be energy-efficient, reducing the power consumption required for AI workloads.
#
# Groq's products have the potential to be used in a variety of applications, including:
#
# 1. **Data centers**: Groq's technology can be used to accelerate AI workloads in data centers, reducing the time and energy required to train and deploy AI models.
# 2. **Edge computing**: Groq's platform can be used in edge computing applications, such as autonomous vehicles, smart homes, and industrial automation.
# 3. **Research and development**: Groq's technology can be used by researchers and developers to accelerate AI research and development, enabling new breakthroughs and innovations.
#
# Overall, Groq is a company that is pushing the boundaries of AI computing, developing innovative hardware and software solutions that can accelerate AI workloads and enable new applications and use cases.

# %%
# !pip install chroma-hnswlib
# Out:
# Collecting chroma-hnswlib
#   Obtaining dependency information for chroma-hnswlib from https://files.pythonhosted.org/packages/3e/79/1bce519cf186112d6d5ce2985392a89528c6e1e9332d680bf752694a4cdf/chroma_hnswlib-0.7.6-cp311-cp311-win_amd64.whl.metadata
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-win_amd64.whl.metadata (262 bytes)
# Requirement already satisfied: numpy in c:\users\shrip\anaconda3\lib\site-packages (from chroma-hnswlib) (1.23.5)
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.9 kB ? eta -:--:--
#    ------- ------------------------------- 30.7/151.9 kB 435.7 kB/s eta 0:00:01
#    ---------------------------- --------- 112.6/151.9 kB 930.9 kB/s eta 0:00:01
#    ---------------------------------------- 151.9/151.9 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: chroma-hnswlib
# Successfully installed chroma-hnswlib-0.7.6

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Obtaining dependency information for chromadb from https://files.pythonhosted.org/packages/28/8e/5c186c77bf749b6fe0528385e507e463f1667543328d76fd00a49e1a4e6a/chromadb-0.6.3-py3-none-any.whl.metadata
#   Downloading chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Obtaining dependency information for build>=1.0.3 from https://files.pythonhosted.org/packages/84/c2/80633736cd183ee4a62107413def345f7e6e3c01563dbca1417363cf957e/build-1.2.2.post1-py3-none-any.whl.metadata
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (2.10.6)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (0.7.6)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Obtaining dependency information for fastapi>=0.95.2 from https://files.pythonhosted.org/packages/8f/7d/2d6ce181d7a5f51dedb8c06206cbf0ec026a99bf145edd309f9e17c3282f/fastapi-0.115.8-py3-none-any.whl.metadata
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Obtaining dependency information for uvicorn[standard]>=0.18.3 from https://files.pythonhosted.org/packages/61/14/33a3a1352cfa71812a3a21e8c9bfb83f60b0011f5e36f2b1399d51928209/uvicorn-0.34.0-py3-none-any.whl.metadata
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (1.23.5)
# Collecting posthog>=2.4.0 (from chromadb)
#   Obtaining dependency information for posthog>=2.4.0 from https://files.pythonhosted.org/packages/e6/21/a7975b832603fed31930860108e12f7680ad829d74ce05eab2df1a17ae2d/posthog-3.11.0-py2.py3-none-any.whl.metadata
#   Downloading posthog-3.11.0-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Obtaining dependency information for onnxruntime>=1.14.1 from https://files.pythonhosted.org/packages/2c/2d/2d4d202c0bcfb3a4cc2b171abb9328672d7f91d7af9ea52572722c6d8d96/onnxruntime-1.20.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading onnxruntime-1.20.1-cp311-cp311-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Obtaining dependency information for opentelemetry-api>=1.2.0 from https://files.pythonhosted.org/packages/43/53/5249ea860d417a26a3a6f1bdedfc0748c4f081a3adaec3d398bc0f7c6a71/opentelemetry_api-1.29.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_api-1.29.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-grpc>=1.2.0 from https://files.pythonhosted.org/packages/f2/de/4b4127a25d1594851d99032f3a9acb09cb512d11edec713410fb906607f4/opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Obtaining dependency information for opentelemetry-instrumentation-fastapi>=0.41b0 from https://files.pythonhosted.org/packages/cb/d6/37784bb30b213e2dd6838b9f96c2940907022c1b75ef1ff18a99afe42433/opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Obtaining dependency information for opentelemetry-sdk>=1.2.0 from https://files.pythonhosted.org/packages/d1/1d/512b86af21795fb463726665e2f61db77d384e8779fdcf4cb0ceec47866d/opentelemetry_sdk-1.29.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_sdk-1.29.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (0.13.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 0.0/67.3 kB ? eta -:--:--
#      ---------------------------------------- 67.3/67.3 kB 1.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (4.65.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Obtaining dependency information for overrides>=7.3.1 from https://files.pythonhosted.org/packages/2c/ab/fc8290c6a4c722e5514d80f62b2dc4c4df1a68a41d1364e625c35990fcf3/overrides-7.7.0-py3-none-any.whl.metadata
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/a4/ed/1f1afb2e9e7f38a545d628f864d562a5ae64fe6f7a10e28ffb9b185b4e89/importlib_resources-6.5.2-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Obtaining dependency information for grpcio>=1.58.0 from https://files.pythonhosted.org/packages/55/15/b6cf2c9515c028aff9da6984761a3ab484a472b0dc6435fcd07ced42127d/grpcio-1.70.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading grpcio-1.70.0-cp311-cp311-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Obtaining dependency information for bcrypt>=4.0.1 from https://files.pythonhosted.org/packages/76/b9/d51d34e6cd6d887adddb28a8680a1d34235cc45b9d6e238ce39b98199ca0/bcrypt-4.2.1-cp39-abi3-win_amd64.whl.metadata
#   Downloading bcrypt-4.2.1-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (0.14.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Obtaining dependency information for kubernetes>=28.1.0 from https://files.pythonhosted.org/packages/df/14/a59acfe4b3095f2a4fd8d13b348853a69c8f1ed4bce9af00d1b31351a88e/kubernetes-32.0.0-py2.py3-none-any.whl.metadata
#   Downloading kubernetes-32.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting tenacity>=8.2.3 (from chromadb)
#   Obtaining dependency information for tenacity>=8.2.3 from https://files.pythonhosted.org/packages/b6/cb/b86984bed139586d01532a587464b5805f12e397594f19f931c4c2fbfa61/tenacity-9.0.0-py3-none-any.whl.metadata
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (6.0)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Obtaining dependency information for mmh3>=4.0.1 from https://files.pythonhosted.org/packages/98/d5/424ba95062d1212ea615dc8debc8d57983f2242d5e6b82e458b89a117a1e/mmh3-5.1.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading mmh3-5.1.0-cp311-cp311-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\shrip\anaconda3\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\shrip\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Obtaining dependency information for pyproject_hooks from https://files.pythonhosted.org/packages/bd/24/12818598c362d7f300f18e74db45963dbcb85150324092410c8b49405e42/pyproject_hooks-1.2.0-py3-none-any.whl.metadata
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\shrip\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Obtaining dependency information for starlette<0.46.0,>=0.40.0 from https://files.pythonhosted.org/packages/d9/61/f2b52e107b1fc8944b33ef56bf6ac4ebbe16d91b94d2b87ce013bf63fb84/starlette-0.45.3-py3-none-any.whl.metadata
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: anyio in c:\users\shrip\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: certifi in c:\users\shrip\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\shrip\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in c:\users\shrip\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\shrip\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\shrip\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\shrip\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for google-auth>=1.0.1 from https://files.pythonhosted.org/packages/9d/47/603554949a37bca5b7f894d51896a9c534b9eab808e2520a748e081669d0/google_auth-2.38.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\shrip\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\shrip\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.31.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for requests-oauthlib from https://files.pythonhosted.org/packages/3b/5d/63d4ae3b9daea098d5d6f5da83984853c1bbacd5dc826764b249fe119d24/requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for oauthlib>=3.2.2 from https://files.pythonhosted.org/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl.metadata
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\shrip\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.16)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for durationpy>=0.7 from https://files.pythonhosted.org/packages/4c/a3/ac312faeceffd2d8f86bc6dcb5c401188ba5a01bc88e69bed97578a0dfcd/durationpy-0.9-py3-none-any.whl.metadata
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for coloredlogs from https://files.pythonhosted.org/packages/a7/06/3d6badcf13db419e25b07041d9c7b4a2c331d3f4e7134445ec5df57714cd/coloredlogs-15.0.1-py2.py3-none-any.whl.metadata
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for flatbuffers from https://files.pythonhosted.org/packages/0e/e2/b066e6e02d67bf5261a6d7539648c6da3365cc9eff3eb6d82009595d84d9/flatbuffers-25.1.24-py2.py3-none-any.whl.metadata
#   Downloading flatbuffers-25.1.24-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for protobuf from https://files.pythonhosted.org/packages/61/fa/aae8e10512b83de633f2646506a6d835b151edf4b30d18d73afd01447253/protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: sympy in c:\users\shrip\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Obtaining dependency information for deprecated>=1.2.6 from https://files.pythonhosted.org/packages/6e/c6/ac0b6c1e2d138f1002bcf799d330bd6d85084fece321e662a14223794041/Deprecated-1.2.18-py2.py3-none-any.whl.metadata
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\shrip\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.0.0)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Obtaining dependency information for googleapis-common-protos~=1.52 from https://files.pythonhosted.org/packages/a0/0f/c0713fb2b3d28af4b2fded3291df1c4d4f79a00d15c2374a9e010870016c/googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Obtaining dependency information for opentelemetry-exporter-otlp-proto-common==1.29.0 from https://files.pythonhosted.org/packages/9e/75/7609bda3d72bf307839570b226180513e854c01443ebe265ed732a4980fc/opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Obtaining dependency information for opentelemetry-proto==1.29.0 from https://files.pythonhosted.org/packages/bd/66/a500e38ee322d89fce61c74bd7769c8ef3bebc6c2f43fda5f3fc3441286d/opentelemetry_proto-1.29.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_proto-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for opentelemetry-instrumentation-asgi==0.50b0 from https://files.pythonhosted.org/packages/d2/81/0899c6b56b1023835f266d909250d439174afa0c34ed5944c5021d3da263/opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for opentelemetry-instrumentation==0.50b0 from https://files.pythonhosted.org/packages/ff/b1/55a77152a83ec8998e520a3a575f44af1020cfe4bdc000b7538583293b85/opentelemetry_instrumentation-0.50b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for opentelemetry-semantic-conventions==0.50b0 from https://files.pythonhosted.org/packages/da/fb/dc15fad105450a015e913cfa4f5c27b6a5f1bea8fb649f8cae11e699c8af/opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for opentelemetry-util-http==0.50b0 from https://files.pythonhosted.org/packages/64/8a/9e1b54f50d1fddebbeac9a9b0632f8db6ece7add904fb593ee2e268ee4de/opentelemetry_util_http-0.50b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\shrip\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Obtaining dependency information for asgiref~=3.0 from https://files.pythonhosted.org/packages/39/e3/893e8757be2612e6c266d9bb58ad2e3651524b5b40cf56761e985a28b13e/asgiref-3.8.1-py3-none-any.whl.metadata
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Obtaining dependency information for monotonic>=1.5 from https://files.pythonhosted.org/packages/9a/67/7e8406a29b6c45be7af7740456f7f37025f0506ae2e05fb9009a53946860/monotonic-1.6-py2.py3-none-any.whl.metadata
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Obtaining dependency information for backoff>=1.10.0 from https://files.pythonhosted.org/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl.metadata
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shrip\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\shrip\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shrip\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shrip\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\shrip\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\shrip\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Obtaining dependency information for httptools>=0.6.3 from https://files.pythonhosted.org/packages/d0/46/4d8e7ba9581416de1c425b8264e2cadd201eb709ec1584c381f3e98f51c1/httptools-0.6.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading httptools-0.6.4-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\shrip\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Obtaining dependency information for watchfiles>=0.13 from https://files.pythonhosted.org/packages/a4/c6/79dc4a7c598a978e5fafa135090aaf7bbb03b8dec7bada437dfbe578e7ed/watchfiles-1.0.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading watchfiles-1.0.4-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in c:\users\shrip\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (10.4)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/ec/4e/de4ff18bcf55857ba18d3a4bd48c8a9fde6bb0980c9d20b263f05387fd88/cachetools-5.5.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.5.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shrip\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl.metadata
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\shrip\anaconda3\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shrip\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrip\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Collecting anyio (from httpx>=0.27.0->chromadb)
#   Obtaining dependency information for anyio from https://files.pythonhosted.org/packages/46/eb/e7f063ad1fec6b3178a3cd82d1a3c4de82cccf283fc42746168188e1cdd5/anyio-4.8.0-py3-none-any.whl.metadata
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shrip\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for humanfriendly>=9.1 from https://files.pythonhosted.org/packages/f0/0f/310fb31e39e2d734ccaa2c0fb981ee41f7bd5056ce9bc29b2248bd569169/humanfriendly-10.0-py2.py3-none-any.whl.metadata
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\shrip\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for pyreadline3 from https://files.pythonhosted.org/packages/5a/dc/491b7661614ab97483abf2056be1deee4dc2490ecbf7bff9ab5cdbac86e1/pyreadline3-3.5.4-py3-none-any.whl.metadata
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\shrip\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Downloading chromadb-0.6.3-py3-none-any.whl (611 kB)
#    ---------------------------------------- 0.0/611.1 kB ? eta -:--:--
#    -------------- ------------------------- 225.3/611.1 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  604.2/611.1 kB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 611.1/611.1 kB 6.4 MB/s eta 0:00:00
# Downloading bcrypt-4.2.1-cp39-abi3-win_amd64.whl (153 kB)
#    ---------------------------------------- 0.0/153.1 kB ? eta -:--:--
#    ---------------------------------------- 153.1/153.1 kB ? eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ---------------------------------------- 0.0/94.8 kB ? eta -:--:--
#    ---------------------------------------- 94.8/94.8 kB ? eta 0:00:00
# Downloading grpcio-1.70.0-cp311-cp311-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.9/4.3 MB 27.5 MB/s eta 0:00:01
#    ------------------------- -------------- 2.8/4.3 MB 35.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 34.4 MB/s eta 0:00:00
# Downloading kubernetes-32.0.0-py2.py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 42.1 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-win_amd64.whl (41 kB)
#    ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#    ---------------------------------------- 41.5/41.5 kB ? eta 0:00:00
# Downloading onnxruntime-1.20.1-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------- ----------------------------- 3.0/11.3 MB 93.4 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.3 MB 74.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.2/11.3 MB 65.5 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 50.4 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.3 kB ? eta -:--:--
#    ---------------------------------------- 64.3/64.3 kB 3.6 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.29.0-py3-none-any.whl (55 kB)
#    ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#    ---------------------------------------- 55.8/55.8 kB ? eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.6 kB ? eta -:--:--
#    ---------------------------------------- 166.6/166.6 kB ? eta 0:00:00
# Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
#    ---------------------------------------- 0.0/118.1 kB ? eta -:--:--
#    ---------------------------------------- 118.1/118.1 kB 6.7 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.11.0-py2.py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------------------------- 72.0/72.0 kB ? eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#    ---------------------------------------- 0.0/210.8 kB ? eta -:--:--
#    --------------------------------------- 210.8/210.8 kB 12.5 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
#    ---------------------------------------- 0.0/221.7 kB ? eta -:--:--
#    --------------------------------------- 221.7/221.7 kB 13.2 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp311-cp311-win_amd64.whl (88 kB)
#    ---------------------------------------- 0.0/88.6 kB ? eta -:--:--
#    ---------------------------------------- 88.6/88.6 kB 4.9 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ---------------------------------------- 151.7/151.7 kB 8.8 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
#    ---------------------------------------- 0.0/434.5 kB ? eta -:--:--
#    ---------------------------------------- 434.5/434.5 kB ? eta 0:00:00
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#    ---------------------------------------- 71.5/71.5 kB 3.8 MB/s eta 0:00:00
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.0 kB ? eta -:--:--
#    ---------------------------------------- 96.0/96.0 kB 5.4 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-win_amd64.whl (284 kB)
#    ---------------------------------------- 0.0/284.2 kB ? eta -:--:--
#    --------------------------------------- 284.2/284.2 kB 18.3 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#    ---------------------------------------- 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# Downloading flatbuffers-25.1.24-py2.py3-none-any.whl (30 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.3 kB ? eta -:--:--
#    ---------------------------------------- 62.3/62.3 kB ? eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading cachetools-5.5.1-py3-none-any.whl (9.5 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.2 kB ? eta -:--:--
#    ---------------------------------------- 83.2/83.2 kB ? eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53885 sha256=ebf340f2e1bc74de1b81caeb308540520614172cc1b44ac708c7eea4d7a12b31
#   Stored in directory: c:\users\shrip\appdata\local\pip\cache\wheels\a3\01\bd\4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, monotonic, flatbuffers, durationpy, tenacity, rsa, pyreadline3, pyproject_hooks, protobuf, overrides, opentelemetry-util-http, oauthlib, mmh3, importlib-resources, httptools, grpcio, deprecated, cachetools, bcrypt, backoff, asgiref, anyio, watchfiles, uvicorn, starlette, requests-oauthlib, posthog, opentelemetry-proto, opentelemetry-api, humanfriendly, googleapis-common-protos, google-auth, build, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, kubernetes, fastapi, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.2
#     Uninstalling tenacity-8.2.2:
#       Successfully uninstalled tenacity-8.2.2
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.5.0
#     Uninstalling anyio-3.5.0:
#       Successfully uninstalled anyio-3.5.0
# Successfully installed anyio-4.8.0 asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.1 build-1.2.2.post1 cachetools-5.5.1 chromadb-0.6.3 coloredlogs-15.0.1 deprecated-1.2.18 durationpy-0.9 fastapi-0.115.8 flatbuffers-25.1.24 google-auth-2.38.0 googleapis-common-protos-1.66.0 grpcio-1.70.0 httptools-0.6.4 humanfriendly-10.0 importlib-resources-6.5.2 kubernetes-32.0.0 mmh3-5.1.0 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.20.1 opentelemetry-api-1.29.0 opentelemetry-exporter-otlp-proto-common-1.29.0 opentelemetry-exporter-otlp-proto-grpc-1.29.0 opentelemetry-instrumentation-0.50b0 opentelemetry-instrumentation-asgi-0.50b0 opentelemetry-instrumentation-fastapi-0.50b0 opentelemetry-proto-1.29.0 opentelemetry-sdk-1.29.0 opentelemetry-semantic-conventions-0.50b0 opentelemetry-util-http-0.50b0 overrides-7.7.0 posthog-3.11.0 protobuf-5.29.3 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rsa-4.9 starlette-0.45.3 tenacity-9.0.0 uvicorn-0.34.0 watchfiles-1.0.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.23.4 requires anyio<4,>=3.1.0, but you have anyio 4.8.0 which is incompatible.
